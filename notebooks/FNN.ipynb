# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, KFold
from keras.utils import to_categorical
from imblearn.over_sampling import SMOTE
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %%
train_path = '../input/credit-dset/clean_trained_outlier.csv'
test_path = '../input/credit-dset/test_cleaned_outlier.csv'

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

if (test_path == '../input/credit-dset/test_cleaned.csv'):
    test_df.drop(['Number'], axis=1, inplace=True)

month_map = {
    'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12
}

# Convert month names to numbers
train_df['Month'] = train_df['Month'].map(month_map)
test_df['Month'] = test_df['Month'].map(month_map)

train_df['Month_sin'] = np.sin(2 * np.pi * train_df['Month'] / 12)
train_df['Month_cos'] = np.cos(2 * np.pi * train_df['Month'] / 12)
test_df['Month_sin'] = np.sin(2 * np.pi * test_df['Month'] / 12)
test_df['Month_cos'] = np.cos(2 * np.pi * test_df['Month'] / 12)
train_df.drop(['Month'], axis=1, inplace=True)
test_df.drop(['Month'], axis=1, inplace=True)

# %%
categorical_cols = []
numerical_cols = []

for col in train_df.columns:
    if col != 'Credit_Score':
        if train_df[col].dtype == 'object':
            categorical_cols.append(col)
        else:
            numerical_cols.append(col)
    else:
        print('Skipping Credit_Score column')

print(categorical_cols)
print(numerical_cols)
# Out:
# Skipping Credit_Score column
# ['Profession', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour']
# ['Age', 'Income_Annual', 'Base_Salary_PerMonth', 'Total_Bank_Accounts', 'Total_Credit_Cards', 'Rate_Of_Interest', 'Delay_from_due_date', 'Total_Delayed_Payments', 'Credit_Limit', 'Total_Credit_Enquiries', 'Current_Debt_Outstanding', 'Ratio_Credit_Utilization', 'Credit_History_Age', 'Per_Month_EMI', 'Monthly_Investment', 'Monthly_Balance', 'Payday Loan', 'Mortgage Loan', 'Debt Consolidation Loan', 'Student Loan', 'Not Specified', 'Auto Loan', 'Credit-Builder Loan', 'Personal Loan', 'Home Equity Loan', 'Total_Current_Loans', 'Month_sin', 'Month_cos']

# %%
# string -> no of months
def convert_to_2_cols(s):
    parts = s.split('_spent_')
    spent = parts[0]
    payment = parts[1].split('_payments')[0]
    return pd.Series([spent,payment])

train_df[['Spent', 'Value_Payments']] = train_df['Payment_Behaviour'].apply(convert_to_2_cols)
train_df.drop(['Payment_Behaviour'], axis=1, inplace=True)

test_df[['Spent', 'Value_Payments']] = test_df['Payment_Behaviour'].apply(convert_to_2_cols)
test_df.drop(['Payment_Behaviour'], axis=1, inplace=True)

# %%
encoder = OneHotEncoder(sparse_output=False)

encoded_columns = encoder.fit_transform(train_df[['Profession', 'Payment_of_Min_Amount']])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(['Profession', 'Payment_of_Min_Amount']))
train_df = pd.concat([train_df, encoded_df], axis=1)

train_df.drop(['Profession', 'Payment_of_Min_Amount'], axis=1, inplace=True)

label_encoder = LabelEncoder()
train_df['Credit_Mix'] = label_encoder.fit_transform(train_df[
    'Credit_Mix'
])

train_df['Spent'] = label_encoder.fit_transform(train_df[
    'Spent'
])

train_df['Value_Payments'] = label_encoder.fit_transform(train_df[
    'Value_Payments'
])

# %%
encoded_columns = encoder.fit_transform(test_df[['Profession', 'Payment_of_Min_Amount']])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(['Profession', 'Payment_of_Min_Amount']))
test_df = pd.concat([test_df, encoded_df], axis=1)

test_df.drop(['Profession', 'Payment_of_Min_Amount'], axis=1, inplace=True)


test_df['Credit_Mix'] = label_encoder.fit_transform(test_df[
    'Credit_Mix'
])

test_df['Spent'] = label_encoder.fit_transform(test_df[
    'Spent'
])

test_df['Value_Payments'] = label_encoder.fit_transform(test_df[
    'Value_Payments'
])

# %%
scaler = StandardScaler()
train_df[numerical_cols] = scaler.fit_transform(train_df[numerical_cols])

label_encoder = LabelEncoder()
train_df['Credit_Score'] = label_encoder.fit_transform(train_df['Credit_Score'])

X = train_df.drop(['Credit_Score'], axis=1)
y = train_df['Credit_Score']
y_categorical = to_categorical(y)

X_train, X_val, y_train, y_val = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

def build_model(input_dim, num_classes):
    model = Sequential([
        Dense(1024, activation=None, input_shape=(input_dim,)),
        LeakyReLU(alpha=0.1),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(512, activation=None),
        LeakyReLU(alpha=0.1),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(256, activation=None),
        LeakyReLU(alpha=0.1),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(128, activation=None),
        LeakyReLU(alpha=0.1),
        BatchNormalization(),
        Dropout(0.2),
        
        Dense(64, activation=None),
        LeakyReLU(alpha=0.1),
        BatchNormalization(),
        Dropout(0.2),
        
        Dense(num_classes, activation='softmax', kernel_regularizer=l2(0.01))
    ])
    return model

# Compile the model
optimizer = Adam(learning_rate=0.001)
model = build_model(X_train.shape[1], y_categorical.shape[1])
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = model.fit(
    X_train_resampled, y_train_resampled,
    validation_data=(X_val, y_val),
    epochs=150,  # Increased epochs for deeper learning
    batch_size=256,  # Increased batch size
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# Evaluate the model
loss, accuracy = model.evaluate(X_val, y_val)
print(f"Validation Loss: {loss:.4f}, Validation Accuracy: {accuracy:.4f}")

# Process the test data
test_df[numerical_cols] = scaler.transform(test_df[numerical_cols])
X_test_final = test_df.drop(['ID'], axis=1)

# Make predictions
test_preds = model.predict(X_test_final)
predicted_classes = test_preds.argmax(axis=1)
predicted_labels = label_encoder.inverse_transform(predicted_classes)

# Create submission file
submission = pd.DataFrame({
    'ID': test_df['ID'], 
    'Credit_Score': predicted_labels
})
submission.to_csv('neural_network_submission.csv', index=False)
print("Submission file 'neural_network_submission.csv' created successfully.")
# Out:
# c:\Users\pchaw\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\pchaw\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - accuracy: 0.6535 - loss: 0.9022 - val_accuracy: 0.6646 - val_loss: 0.7705 - learning_rate: 0.0010
# Epoch 2/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.7319 - loss: 0.6731 - val_accuracy: 0.6720 - val_loss: 0.7581 - learning_rate: 0.0010
# Epoch 3/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.7443 - loss: 0.6385 - val_accuracy: 0.6786 - val_loss: 0.7431 - learning_rate: 0.0010
# Epoch 4/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7490 - loss: 0.6180 - val_accuracy: 0.6754 - val_loss: 0.7109 - learning_rate: 0.0010
# Epoch 5/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.7582 - loss: 0.5944 - val_accuracy: 0.6859 - val_loss: 0.7101 - learning_rate: 0.0010
# Epoch 6/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7612 - loss: 0.5805 - val_accuracy: 0.6854 - val_loss: 0.7329 - learning_rate: 0.0010
# Epoch 7/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7661 - loss: 0.5698 - val_accuracy: 0.6997 - val_loss: 0.6952 - learning_rate: 0.0010
# Epoch 8/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7729 - loss: 0.5529 - val_accuracy: 0.6911 - val_loss: 0.6902 - learning_rate: 0.0010
# Epoch 9/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7785 - loss: 0.5419 - val_accuracy: 0.7023 - val_loss: 0.6780 - learning_rate: 0.0010
# Epoch 10/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7815 - loss: 0.5325 - val_accuracy: 0.7055 - val_loss: 0.6787 - learning_rate: 0.0010
# Epoch 11/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.7863 - loss: 0.5199 - val_accuracy: 0.7117 - val_loss: 0.6656 - learning_rate: 0.0010
# Epoch 12/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.7942 - loss: 0.5036 - val_accuracy: 0.7130 - val_loss: 0.6555 - learning_rate: 0.0010
# Epoch 13/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8007 - loss: 0.4908 - val_accuracy: 0.7147 - val_loss: 0.6534 - learning_rate: 0.0010
# Epoch 14/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8027 - loss: 0.4865 - val_accuracy: 0.7186 - val_loss: 0.6576 - learning_rate: 0.0010
# Epoch 15/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8085 - loss: 0.4745 - val_accuracy: 0.7204 - val_loss: 0.6396 - learning_rate: 0.0010
# Epoch 16/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8123 - loss: 0.4657 - val_accuracy: 0.7268 - val_loss: 0.6394 - learning_rate: 0.0010
# Epoch 17/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8117 - loss: 0.4644 - val_accuracy: 0.7264 - val_loss: 0.6369 - learning_rate: 0.0010
# Epoch 18/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8202 - loss: 0.4494 - val_accuracy: 0.7258 - val_loss: 0.6561 - learning_rate: 0.0010
# Epoch 19/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8221 - loss: 0.4443 - val_accuracy: 0.7253 - val_loss: 0.6481 - learning_rate: 0.0010
# Epoch 20/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8232 - loss: 0.4388 - val_accuracy: 0.7224 - val_loss: 0.6616 - learning_rate: 0.0010
# Epoch 21/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8278 - loss: 0.4292 - val_accuracy: 0.7345 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 22/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8315 - loss: 0.4254 - val_accuracy: 0.7406 - val_loss: 0.6177 - learning_rate: 0.0010
# Epoch 23/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8341 - loss: 0.4172 - val_accuracy: 0.7433 - val_loss: 0.6082 - learning_rate: 0.0010
# Epoch 24/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8347 - loss: 0.4149 - val_accuracy: 0.7418 - val_loss: 0.6105 - learning_rate: 0.0010
# Epoch 25/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8402 - loss: 0.4047 - val_accuracy: 0.7486 - val_loss: 0.6024 - learning_rate: 0.0010
# Epoch 26/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8421 - loss: 0.3996 - val_accuracy: 0.7464 - val_loss: 0.6111 - learning_rate: 0.0010
# Epoch 27/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8439 - loss: 0.3968 - val_accuracy: 0.7506 - val_loss: 0.5881 - learning_rate: 0.0010
# Epoch 28/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8451 - loss: 0.3912 - val_accuracy: 0.7527 - val_loss: 0.5982 - learning_rate: 0.0010
# Epoch 29/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8471 - loss: 0.3915 - val_accuracy: 0.7541 - val_loss: 0.6049 - learning_rate: 0.0010
# Epoch 30/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8483 - loss: 0.3862 - val_accuracy: 0.7540 - val_loss: 0.6041 - learning_rate: 0.0010
# Epoch 31/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8503 - loss: 0.3804 - val_accuracy: 0.7563 - val_loss: 0.5947 - learning_rate: 0.0010
# Epoch 32/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8508 - loss: 0.3766 - val_accuracy: 0.7579 - val_loss: 0.5972 - learning_rate: 0.0010
# Epoch 33/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8598 - loss: 0.3601 - val_accuracy: 0.7645 - val_loss: 0.5790 - learning_rate: 5.0000e-04
# Epoch 34/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8632 - loss: 0.3494 - val_accuracy: 0.7681 - val_loss: 0.5839 - learning_rate: 5.0000e-04
# Epoch 35/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8646 - loss: 0.3486 - val_accuracy: 0.7688 - val_loss: 0.5724 - learning_rate: 5.0000e-04
# Epoch 36/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8680 - loss: 0.3418 - val_accuracy: 0.7706 - val_loss: 0.5800 - learning_rate: 5.0000e-04
# Epoch 37/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8704 - loss: 0.3362 - val_accuracy: 0.7739 - val_loss: 0.5723 - learning_rate: 5.0000e-04
# Epoch 38/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8708 - loss: 0.3361 - val_accuracy: 0.7732 - val_loss: 0.5780 - learning_rate: 5.0000e-04
# Epoch 39/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8715 - loss: 0.3327 - val_accuracy: 0.7717 - val_loss: 0.5874 - learning_rate: 5.0000e-04
# Epoch 40/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8728 - loss: 0.3275 - val_accuracy: 0.7701 - val_loss: 0.5736 - learning_rate: 5.0000e-04
# Epoch 41/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8743 - loss: 0.3238 - val_accuracy: 0.7751 - val_loss: 0.5789 - learning_rate: 2.5000e-04
# Epoch 42/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8772 - loss: 0.3170 - val_accuracy: 0.7760 - val_loss: 0.5786 - learning_rate: 2.5000e-04
# Epoch 43/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8794 - loss: 0.3120 - val_accuracy: 0.7768 - val_loss: 0.5703 - learning_rate: 2.5000e-04
# Epoch 44/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8819 - loss: 0.3064 - val_accuracy: 0.7792 - val_loss: 0.5735 - learning_rate: 2.5000e-04
# Epoch 45/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8828 - loss: 0.3031 - val_accuracy: 0.7784 - val_loss: 0.5767 - learning_rate: 2.5000e-04
# Epoch 46/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8782 - loss: 0.3130 - val_accuracy: 0.7796 - val_loss: 0.5768 - learning_rate: 2.5000e-04
# Epoch 47/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8798 - loss: 0.3094 - val_accuracy: 0.7789 - val_loss: 0.5703 - learning_rate: 2.5000e-04
# Epoch 48/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8848 - loss: 0.3017 - val_accuracy: 0.7783 - val_loss: 0.5793 - learning_rate: 2.5000e-04
# Epoch 49/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8856 - loss: 0.2964 - val_accuracy: 0.7818 - val_loss: 0.5749 - learning_rate: 1.2500e-04
# Epoch 50/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8839 - loss: 0.3023 - val_accuracy: 0.7824 - val_loss: 0.5788 - learning_rate: 1.2500e-04
# Epoch 51/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8840 - loss: 0.3019 - val_accuracy: 0.7824 - val_loss: 0.5766 - learning_rate: 1.2500e-04
# Epoch 52/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8839 - loss: 0.2997 - val_accuracy: 0.7839 - val_loss: 0.5734 - learning_rate: 1.2500e-04
# Epoch 53/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8883 - loss: 0.2918 - val_accuracy: 0.7837 - val_loss: 0.5776 - learning_rate: 1.2500e-04
# Epoch 54/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8875 - loss: 0.2943 - val_accuracy: 0.7821 - val_loss: 0.5777 - learning_rate: 6.2500e-05
# Epoch 55/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8883 - loss: 0.2912 - val_accuracy: 0.7841 - val_loss: 0.5771 - learning_rate: 6.2500e-05
# Epoch 56/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8886 - loss: 0.2902 - val_accuracy: 0.7851 - val_loss: 0.5754 - learning_rate: 6.2500e-05
# Epoch 57/150
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8873 - loss: 0.2922 - val_accuracy: 0.7830 - val_loss: 0.5774 - learning_rate: 6.2500e-05
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7785 - loss: 0.5756
# Validation Loss: 0.5703, Validation Accuracy: 0.7789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Submission file 'neural_network_submission.csv' created successfully.
